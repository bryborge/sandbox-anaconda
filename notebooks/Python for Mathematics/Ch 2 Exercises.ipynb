# %% [markdown]
# # Chapter 2 Exercises

# %%
3+8
# Out:
# 11

# %%
3/7
# Out:
# 0.42857142857142855

# %%
456/21
# Out:
# 21.714285714285715

# %%
(4 ** 3 + 2) / (2 * 5) - 5**0.5
# Out:
# 4.36393202250021

# %% [markdown]
# ## Euler's Equation
#
# $$
# e^{i\pi} = -1
# $$

# %% [markdown]
# $$
# \frac{4^{3} + 2}{2 \times 5}
# $$

# %% [markdown]
# $$
#  - 5^{\frac{1}{2}}
# $$

# %% [markdown]
# $$
# \frac{df}{dx}
# $$

# %% [markdown]
# $$
# \int_{5}^{12} x^{2} dx
# $$

# %% [markdown]
# $$
# \begin{pmatrix}
#     4&12&3\\
#     2&x&i\\
# \end{pmatrix}
# $$
